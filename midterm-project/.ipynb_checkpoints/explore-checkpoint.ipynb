# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Preparation

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df['Churn'] = (df['Churn'] == 'Yes').astype(int)

# %%
df.duplicated().value_counts()
# Out:
# False    7043
# dtype: int64

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train['Churn']
y_val = df_val['Churn']
y_test = df_test['Churn']

del df_train['Churn']
del df_val['Churn']
del df_test['Churn']

# %%
df_train.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  8015-IHCGW  Female              0     Yes        Yes      72          Yes
# 1  1960-UYCNN    Male              0      No         No      10          Yes
# 2  9250-WYPLL  Female              0      No         No       5          Yes
# 3  6786-OBWQR  Female              0     Yes        Yes       5          Yes
# 4  1328-EUZHC  Female              0     Yes         No      18          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                  Yes                  Yes
# 1           Yes     Fiber optic                   No                  Yes
# 2           Yes     Fiber optic                   No                   No
# 3            No     Fiber optic                   No                   No
# 4            No              No  No internet service  No internet service
#
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Numeric Features

# %%
df_full_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5634 entries, 1814 to 5157
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   object
#  1   gender            5634 non-null   object
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   object
#  4   Dependents        5634 non-null   object
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   object
#  7   MultipleLines     5634 non-null   object
#  8   InternetService   5634 non-null   object
#  9   OnlineSecurity    5634 non-null   object
#  10  OnlineBackup      5634 non-null   object
#  11  DeviceProtection  5634 non-null   object
#  12  TechSupport       5634 non-null   object
#  13  StreamingTV       5634 non-null   object
#  14  StreamingMovies   5634 non-null   object
#  15  Contract          5634 non-null   object
# ...

# %%
num_feat = list(df_full_train.select_dtypes(include=['int64', 'float64']).columns)
num_feat.remove('SeniorCitizen') # This is a binary data
num_feat.remove('Churn') # This is a binary data

# %%
num_feat
# Out:
# ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
df_full_train[num_feat].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  5634.000000     5634.000000   5626.000000
# mean     32.277955       64.779127   2280.662380
# std      24.555211       30.104993   2266.394623
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.400000    391.900000
# 50%      29.000000       70.375000   1394.800000
# 75%      55.000000       89.850000   3794.487500
# max      72.000000      118.650000   8684.800000

# %%
df_full_train[num_feat].describe(percentiles=[.0, .25, .5, .75, .9, .95, .99, .1]).T
# Out:
#                  count         mean          std    min     0%    10%    25%  \
# tenure          5634.0    32.277955    24.555211   0.00   0.00   2.00    9.0
# MonthlyCharges  5634.0    64.779127    30.104993  18.25  18.25  20.05   35.4
# TotalCharges    5626.0  2280.662380  2266.394623  18.80  18.80  84.60  391.9
#
#                      50%        75%      90%        95%        99%      max
# tenure            29.000    55.0000    69.00    72.0000    72.0000    72.00
# MonthlyCharges    70.375    89.8500   102.60   107.4175   114.7335   118.65
# TotalCharges    1394.800  3794.4875  5968.85  6906.6000  8010.5125  8684.80

# %%
fig, ax = plt.subplots(6, figsize=(10, 15))
sns.set(font_scale=.5)

g=sns.boxplot(data=df_full_train, x="tenure", ax=ax[0])
g=sns.histplot(data=df_full_train, x="tenure", ax=ax[1])


g=sns.boxplot(data=df_full_train, x="MonthlyCharges", ax=ax[2])
g=sns.histplot(data=df_full_train, x="MonthlyCharges", ax=ax[3])


g=sns.boxplot(data=df_full_train, x="TotalCharges", ax=ax[4])
g=sns.histplot(data=df_full_train, x="TotalCharges", ax=ax[5])

plt.tight_layout()

# %%
fig, ax = plt.subplots(6, figsize=(30, 55))
sns.set(font_scale=2)

g=sns.boxplot(data=df_full_train, x="tenure", y="Churn", ax=ax[0], hue="Churn")
g=sns.histplot(data=df_full_train, x="tenure", ax=ax[1], hue="Churn")


g=sns.boxplot(data=df_full_train, x="MonthlyCharges", y="Churn", ax=ax[2], hue="Churn")
g=sns.histplot(data=df_full_train, x="MonthlyCharges", ax=ax[3], hue="Churn")


g=sns.boxplot(data=df_full_train, x="TotalCharges", y="Churn", ax=ax[4], hue="Churn")
g=sns.histplot(data=df_full_train, x="TotalCharges", ax=ax[5], hue="Churn")

# %%
df_full_train[num_feat].corrwith(df_full_train.Churn)
# Out:
# tenure           -0.351885
# MonthlyCharges    0.196805
# TotalCharges     -0.197416
# dtype: float64

# %%
import pandas as pd
from scipy.stats import pointbiserialr

pbc = pointbiserialr(df_full_train['MonthlyCharges'], df_full_train['Churn'])
print(pbc)
# Out:
# PointbiserialrResult(correlation=0.19680530682529063, pvalue=2.63215879980694e-50)

# %%
pbc = pointbiserialr(df_full_train['tenure'], df_full_train['Churn'])
print(pbc)
# Out:
# PointbiserialrResult(correlation=-0.3518852391159017, pvalue=6.576292127922218e-164)

# %% [markdown]
# ## Categorical Features
